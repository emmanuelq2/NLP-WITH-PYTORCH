# %%
# !pip install torchtext==0.16.0 torch==2.1.0
# Out:
# Collecting torchtext==0.16.0
#   Using cached torchtext-0.16.0-cp310-cp310-manylinux1_x86_64.whl (2.0 MB)
# Collecting torch==2.1.0
#   Downloading torch-2.1.0-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext==0.16.0) (4.66.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext==0.16.0) (2.31.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchtext==0.16.0) (1.23.5)
# Collecting torchdata==0.7.0 (from torchtext==0.16.0)
#   Downloading torchdata-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 71.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.1.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 52.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.1.0)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 54.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.1.0)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 64.4 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.1.0)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.1.0)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.8 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.1.0)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.1.0)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.5 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.1.0)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.1.0)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.6 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.18.1 (from torch==2.1.0)
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 6.4 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.1.0)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 16.3 MB/s eta 0:00:00
# Collecting triton==2.1.0 (from torch==2.1.0)
#   Downloading triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 9.5 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.0)
#   Downloading nvidia_nvjitlink_cu12-12.2.140-py3-none-manylinux1_x86_64.whl (20.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 80.5 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.10/dist-packages (from torchdata==0.7.0->torchtext==0.16.0) (2.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.1.0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.16.0) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.16.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.16.0) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1.0) (1.3.0)
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchdata, torchtext
#   Attempting uninstall: triton
#     Found existing installation: triton 2.0.0
#     Uninstalling triton-2.0.0:
#       Successfully uninstalled triton-2.0.0
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0
#     Uninstalling torch-1.11.0:
#       Successfully uninstalled torch-1.11.0
# ERROR: Operation cancelled by user

# %%
import torch
from torchtext import data, datasets
import random

# %%
seed = 966
torch.manual_seed(seed)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# **Fields**
#
# [Check documentation](https://pytorch.org/text/_modules/torchtext/data/field.html)

# %%
nlp = spacy.load("en_core_web_sm")
# define fields
TEXT = data.Field(tokenize=nlp, lower=True)
LABEL = data.LabelField()

# %% [markdown]
# **Text REtrieval Conference (TREC) Question Classification Dataset**
#
# *Data Examples and Six Categories:*
#
# | Text | Label | Category |
# | --- | --- | --- |
# |CNN is the abbreviation for what ?|ABBR| ABBREVIATION |
# | What is the date of Boxing Day ? | NUM |NUMERIC|
# |Who discovered electricity ?| HUM |HUMAN|
# |What 's the colored part of the eye called ?|ENTY|ENTITY|
# |Why do horseshoes bring luck ?|DESC|DESCRIPTION|
# |What is California 's capital ?|LOC|LOCATION|

# %%
train, test = datasets.TREC.splits(TEXT, LABEL)
train, val = train.split(random_state=random.seed(seed))
# Out:
# downloading train_5500.label
# train_5500.label: 100%|██████████| 336k/336k [00:00<00:00, 3.08MB/s]
# downloading TREC_10.label
# TREC_10.label: 100%|██████████| 23.4k/23.4k [00:00<00:00, 907kB/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-73192f83a52f> in <cell line: 1>()
# ----> 1 train, test = datasets.TREC.splits(TEXT, LABEL)
#       2 train, val = train.split(random_state=random.seed(seed))
#
# /usr/local/lib/python3.10/dist-packages/torchtext/datasets/trec.py in splits(cls, text_field, label_field, root, train, test, **kwargs)
#      57                 Dataset.
#      58         """
# ---> 59         return super(TREC, cls).splits(
#      60             root=root, text_field=text_field, label_field=label_field,
#      61             train=train, validation=None, test=test, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/torchtext/data/dataset.py in splits(cls, path, root, train, validation, test, **kwargs)
#      75         if path is None:
#      76             path = cls.download(root)
# ---> 77         train_data = None if train is None else cls(
#      78             os.path.join(path, train), **kwargs)
#      79         val_data = None if validation is None else cls(
#
# /usr/local/lib/python3.10/dist-packages/torchtext/datasets/trec.py in __init__(self, path, text_field, label_field, fine_grained, **kwargs)
#      38             # there is one non-ASCII byte: sisterBADBYTEcity; replaced with space
#      39             label, _, text = line.replace(b'\xf0', b' ').decode().partition(' ')
# ---> 40             examples.append(data.Example.fromlist([text, label], fields))
#      41
#      42         super(TREC, self).__init__(examples, fields, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/torchtext/data/example.py in fromlist(cls, data, fields)
#      83                         setattr(ex, n, f.preprocess(val))
#      84                 else:
# ---> 85                     setattr(ex, name, field.preprocess(val))
#      86         return ex
#      87
#
# /usr/local/lib/python3.10/dist-packages/torchtext/data/field.py in preprocess(self, x)
#     215             x = self.tokenize(x.rstrip('\n'))
#     216         if self.lower:
# --> 217             x = Pipeline(six.text_type.lower)(x)
#     218         if self.sequential and self.use_vocab and self.stop_words is not None:
#     219             x = [w for w in x if w not in self.stop_words]
#
# /usr/local/lib/python3.10/dist-packages/torchtext/data/pipeline.py in __call__(self, x, *args)
#      36         """
#      37         for pipe in self.pipes:
# ---> 38             x = pipe.call(x, *args)
#      39         return x
#      40
#
# /usr/local/lib/python3.10/dist-packages/torchtext/data/pipeline.py in call(self, x, *args)
#      52         if isinstance(x, list):
#      53             return [self.convert_token(tok, *args) for tok in x]
# ---> 54         return self.convert_token(x, *args)
#      55
#      56     def add_before(self, pipeline):
#
# TypeError: descriptor 'lower' for 'str' objects doesn't apply to a 'spacy.tokens.doc.Doc' object

# %%
vars(train[-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-32a4bd621e3a> in <cell line: 1>()
# ----> 1 vars(train[-1])
#
# NameError: name 'train' is not defined

# %%
# build vocab

# %%
print(LABEL.vocab.stoi)

# %%
print("Vocabulary size of TEXT:",len(TEXT.vocab.stoi))
print("Vocabulary size of LABEL:",len(LABEL.vocab.stoi))

# %%
train_iterator, valid_iterator, test_iterator = data.BucketIterator.splits(
    (train, val, test),
    batch_size = 64,
    sort_key=lambda x: len(x.text),
    device=device
)
